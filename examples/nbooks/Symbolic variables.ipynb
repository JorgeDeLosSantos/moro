# %% [markdown]
# # Symbolic variables
#
# Below are listed and displayed symbolic variables that are predefined and loaded into the workspace when `moro` is imported.

# %%
from moro import *

# %% [markdown]
# # Joint variables (time dependent)

# %%
q1,q2,q3,q4,q5,q6
# Out:
# (q₁, q₂, q₃, q₄, q₅, q₆)

# %% [markdown]
# Also velocities and accelerations are defined:

# %%
q1p, q2p, q3p, q4p, q5p, q6p
# Out:
# (q₁̇, q₂̇, q₃̇, q₄̇, q₅̇, q₆̇)

# %%
q1pp, q2pp, q3pp, q4pp, q5pp, q6pp
# Out:
# (q₁̈, q₂̈, q₃̈, q₄̈, q₅̈, q₆̈)

# %% [markdown]
# ## Greek letters

# %%
alpha,beta,gamma,delta,epsilon,zeta,eta,theta
# Out:
# (α, β, γ, δ, ε, ζ, η, θ)

# %%
iota,kappa,mu,nu,xi,omicron,rho,sigma
# Out:
# (ι, κ, μ, ν, ξ, ο, ρ, σ)

# %%
tau,upsilon,phi,chi,psi,omega
# Out:
# (τ, υ, φ, χ, ψ, ω)

# %% [markdown]
# ## Other symbols

# %%
d1, d2, d3, d4, d5, d6
# Out:
# (d₁, d₂, d₃, d₄, d₅, d₆)

# %%
t1, t2, t3, t4, t5, t6
# Out:
# (θ₁, θ₂, θ₃, θ₄, θ₅, θ₆)

# %%
l1, l2, l3, l4, l5, l6
# Out:
# (l₁, l₂, l₃, l₄, l₅, l₆)

# %%
a1, a2, a3, a4, a5, a6
# Out:
# (a₁, a₂, a₃, a₄, a₅, a₆)

# %% [markdown]
# ## For dynamic modeling
#
# Masses:

# %%
m1, m2, m3, m4, m5, m6
# Out:
# (m₁, m₂, m₃, m₄, m₅, m₆)

# %% [markdown]
# Center of mass distances:

# %%
lc1,lc2,lc3,lc4,lc5,lc6
# Out:
# (l_c1, l_c2, l_c3, l_c4, l_c5, l_c6)

# %% [markdown]
# Gravity:

# %%
g
# Out:
# g

# %% [markdown]
# Consider that $q_i$ variables are the only time depent, so if you compute:
#
# $$ \frac{dq_i}{dt}  = \dot{q}_i $$

# %%
q1.diff(t)
# Out:
# q₁̇

# %% [markdown]
# But if you compute the derivative with respect to time of any other variable, you get zero:

# %%
l1.diff(t), lc1.diff(t), d1.diff(t)
# Out:
# (0, 0, 0)
