# %%
from moro import *

# %%
RRP = Robot((0,pi/2,d1,q1,"r"), (0,pi/2,0,q2,"r"), (0,0,q3,0,"p"))

# %%
RRP.J
# Out:
# ⎡-q₃⋅sin(q₁)⋅sin(q₂)  q₃⋅cos(q₁)⋅cos(q₂)  sin(q₂)⋅cos(q₁)⎤
# ⎢                                                        ⎥
# ⎢q₃⋅sin(q₂)⋅cos(q₁)   q₃⋅sin(q₁)⋅cos(q₂)  sin(q₁)⋅sin(q₂)⎥
# ⎢                                                        ⎥
# ⎢         0               q₃⋅sin(q₂)         -cos(q₂)    ⎥
# ⎢                                                        ⎥
# ⎢         0                sin(q₁)               0       ⎥
# ⎢                                                        ⎥
# ⎢         0                -cos(q₁)              0       ⎥
# ⎢                                                        ⎥
# ⎣         1                   0                  0       ⎦

# %%
RRP.w_i(1)
# Out:
# ⎡0 ⎤
# ⎢  ⎥
# ⎢0 ⎥
# ⎢  ⎥
# ⎣q₁̇⎦

# %%
# Out:
# ⎡sin(q₁)⋅q₂̇ ⎤
# ⎢           ⎥
# ⎢-cos(q₁)⋅q₂̇⎥
# ⎢           ⎥
# ⎣    q₁̇     ⎦
