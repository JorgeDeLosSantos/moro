# %%
from moro import *
import moro.abc as abc

# %%
r = Robot((l1,0,0,t1,"r"), (l2,0,0,t2,"r"))

# %%
r.J
# Out:
# ⎡-l₁⋅sin(θ₁) - l₂⋅sin(θ₁ + θ₂)  -l₂⋅sin(θ₁ + θ₂)⎤
# ⎢                                               ⎥
# ⎢l₁⋅cos(θ₁) + l₂⋅cos(θ₁ + θ₂)   l₂⋅cos(θ₁ + θ₂) ⎥
# ⎢                                               ⎥
# ⎢              0                       0        ⎥
# ⎢                                               ⎥
# ⎢              0                       0        ⎥
# ⎢                                               ⎥
# ⎢              0                       0        ⎥
# ⎢                                               ⎥
# ⎣              1                       1        ⎦

# %%
abc.available_symvars
# Out:
# [g, t, q₁, q₂, q₃, q₄, q₅, q₆, q₁̇, q₂̇, q₃̇, q₄̇, q₅̇, q₆̇, q₁̈, q₂̈, q₃̈, q₄
# ̈, q₅̈, q₆̈, θ₁, θ₂, θ₃, θ₄, θ₅, θ₆, l₁, l₂, l₃, l₄, l₅, l₆, l_c1, l_c2, l_c3,
#  l_c4, l_c5, l_c6, d₁, d₂, d₃, d₄, d₅, d₆, m₁, m₂, m₃, m₄, m₅, m₆, a₁, a₂, a₃,
#  a₄, a₅, a₆, x₀, x₁, x₂, x₃, x₄, x₅, x₆, y₀, y₁, y₂, y₃, y₄, y₅, y₆, z₀, z₁, z
# ₂, z₃, z₄, z₅, z₆, α, β, γ, δ, ε, ζ, η, θ, ι, κ, μ, ν, ξ, ο, ρ, σ, τ, υ, φ, χ,
#  ψ, ω]
