# %%
from moro import *

# %%
RRR = Robot((0,pi/2,d1,q1), (l2,0,0,q2), (l3,0,0,q3))
RRR
# Out:
# Robot RRR

# %%
RRR.T
# Out:
# ⎡cos(q₂ + q₃)⋅cos(q₁)  -sin(q₂ + q₃)⋅cos(q₁)  sin(q₁)   (l₂⋅cos(q₂) + l₃⋅cos(q₂ + q₃))⋅cos(q₁)⎤
# ⎢                                                                                             ⎥
# ⎢sin(q₁)⋅cos(q₂ + q₃)  -sin(q₂ + q₃)⋅sin(q₁)  -cos(q₁)  (l₂⋅cos(q₂) + l₃⋅cos(q₂ + q₃))⋅sin(q₁)⎥
# ⎢                                                                                             ⎥
# ⎢    sin(q₂ + q₃)          cos(q₂ + q₃)          0        d₁ + l₂⋅sin(q₂) + l₃⋅sin(q₂ + q₃)   ⎥
# ⎢                                                                                             ⎥
# ⎣         0                      0               0                        1                   ⎦

# %%
RRR.T_ij(3,1)
# Out:
# ⎡cos(q₂ + q₃)  -sin(q₂ + q₃)  0  l₂⋅cos(q₂) + l₃⋅cos(q₂ + q₃)⎤
# ⎢                                                            ⎥
# ⎢sin(q₂ + q₃)  cos(q₂ + q₃)   0  l₂⋅sin(q₂) + l₃⋅sin(q₂ + q₃)⎥
# ⎢                                                            ⎥
# ⎢     0              0        1               0              ⎥
# ⎢                                                            ⎥
# ⎣     0              0        0               1              ⎦
