# %%
from moro import *

# %%
R = rotx(pi/4)*roty(pi)
R
# Out:
# ⎡-1  0    0  ⎤
# ⎢            ⎥
# ⎢    √2   √2 ⎥
# ⎢0   ──   ── ⎥
# ⎢    2    2  ⎥
# ⎢            ⎥
# ⎢    √2  -√2 ⎥
# ⎢0   ──  ────⎥
# ⎣    2    2  ⎦

# %%
k,t = rot2axa(R)

# %%
simplify( axa2rot(k,t) )
# Out:
# ⎡-1  0    0  ⎤
# ⎢            ⎥
# ⎢    √2   √2 ⎥
# ⎢0   ──   ── ⎥
# ⎢    2    2  ⎥
# ⎢            ⎥
# ⎢    √2  -√2 ⎥
# ⎢0   ──  ────⎥
# ⎣    2    2  ⎦
