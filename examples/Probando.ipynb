# %%
from moro import *

# %%
RP = Robot((0,pi/2,0,q1), (0,0,q2,0,"p"))

# %%
RP.masses = None
RP.inertia_tensors = None
RP.gravity = (0,-g,0)
RP.cm_positions = [[0,0,lc1], [0,0,0]]

# %%
RP.dynamic_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 RP.dynamic_model()
#
# File g:\my drive\r&d\proyectos\moro\moro\moro\core.py:1013, in Robot.dynamic_model(self)
#    1002 def dynamic_model(self):
#    1003     """
#    1004     Returns the dynamic model of the robot
#    1005     using the Euler-Lagrange formulation. The returned value is a list of equations,
#    (...)
#    1011     where :math:`\\mathcal{L}` is the Lagrangian of the system, defined as :math:`\\mathcal{L} = \\mathcal{K} - \\mathcal{P}`, where :math:`\\mathcal{K}` is the kinetic energy and :math:`\\mathcal{P}` is the potential energy.
#    1012     """
# -> 1013     L = self.lagrangian()
#    1014     equations = []
#    1015     for i in range(self.dof):
#
# File g:\my drive\r&d\proyectos\moro\moro\moro\core.py:998, in Robot.lagrangian(self)
#     994 """
# ...

# %%
RP.dynamic_model_matrix_form()

# %%
RP.potential
