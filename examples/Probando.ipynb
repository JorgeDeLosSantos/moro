# %%
from moro import *

# %%
RP = Robot((0,pi/2,0,q1), (0,0,q2,0,"p"))

# %%
RP.masses = None
RP.inertia_tensors = None
RP.gravity = (0,-g,0)
RP.cm_positions = [[0,0,lc1], [0,0,0]]

# %%
RP.dynamic_model()
# Out:
# ⎡                                                                          2              2                            ↪
# ⎣I_{y_1y_1}⋅q₁̈ + I_{y_2y_2}⋅q₁̈ + g⋅l_c1⋅m₁⋅sin(q₁) + g⋅m₂⋅q₂⋅sin(q₁) + l_c1 ⋅m₁⋅q₁̈ + m₂⋅q₂ ⋅q₁̈ + 2⋅m₂⋅q₂⋅q₁̇⋅q₂̇ = τ₁, m ↪
#
# ↪   ⎛                  2     ⎞     ⎤
# ↪ ₂⋅⎝-g⋅cos(q₁) - q₂⋅q₁̇  + q₂̈⎠ = τ₂⎦

# %%
RP.dynamic_model_matrix_form()
# Out:
# ⎡                              2           2    ⎤                                                                      ↪
# ⎢I_{y_1y_1} + I_{y_2y_2} + l_c1 ⋅m₁ + m₂⋅q₂   0 ⎥ ⎡q₁̈⎤   ⎡m₂⋅q₂⋅q₂̇   m₂⋅q₂⋅q₁̇⎤ ⎡q₁̇⎤   ⎡g⋅l_c1⋅m₁⋅sin(q₁) + g⋅m₂⋅q₂⋅sin ↪
# ⎢                                               ⎥⋅⎢  ⎥ + ⎢                   ⎥⋅⎢  ⎥ + ⎢                                ↪
# ⎣                     0                       m₂⎦ ⎣q₂̈⎦   ⎣-m₂⋅q₂⋅q₁̇     0    ⎦ ⎣q₂̇⎦   ⎣           -g⋅m₂⋅cos(q₁)        ↪
#
# ↪
# ↪ (q₁)⎤   ⎡τ₁⎤
# ↪     ⎥ = ⎢  ⎥
# ↪     ⎦   ⎣τ₂⎦
